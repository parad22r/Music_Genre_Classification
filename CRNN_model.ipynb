# %%
# %tensorflow_version 1.x

import numpy as np
import os
from os.path import isfile
import keras
from keras.models import Sequential, Model
from keras.layers import Input, Dense, TimeDistributed, LSTM, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, Flatten, Conv2D, BatchNormalization, Lambda, SeparableConv1D
from keras.layers.advanced_activations import ELU
from keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from keras import backend
from keras.utils import np_utils
from keras.optimizers import Adam, RMSprop

from keras import regularizers

from google.colab import drive

import librosa
import librosa.display
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Load training and Validation arrays

# %%
dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 
               'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7  }


reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Electronic', 1: 'Experimental', 2: 'Folk', 3: 'Hip-Hop', 4: 'Instrumental', 5: 'International', 6: 'Pop', 7: 'Rock'}

# %%
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
npzfile = np.load("/content/drive/My Drive/Music_Genre_files_for_github/shuffled_train.npz")
print(npzfile.files)
X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394, 8)

# %%
npzfile = np.load("/content/drive/My Drive/Music_Genre_files_for_github/shuffled_valid.npz")
print(npzfile.files)
X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800, 8)

# %% [markdown]
# ### Check by plotting a Spectogram

# %%
num = 5300
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram')
plt.tight_layout()
# Out:
# Experimental

# %% [markdown]
# ### CNN - RNN Model

# %%
batch_size = 32
num_classes = 8
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
N_LAYERS = 3
FILTER_LENGTH = 5
CONV_FILTER_COUNT = 56
BATCH_SIZE = 32
LSTM_COUNT = 96
EPOCH_COUNT = 70
NUM_HIDDEN = 64
L2_regularization = 0.005

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### 3 1D Convolution Layers
    for i in range(N_LAYERS):
        # give name to the layers
        layer = SeparableConv1D(
                filters=CONV_FILTER_COUNT,
                kernel_size=FILTER_LENGTH,
                kernel_regularizer=regularizers.l2(L2_regularization),  # Tried 0.001
                name='convolution_' + str(i + 1)
            )(layer)
        layer = BatchNormalization(momentum=0.9)(layer)
        layer = Activation('relu')(layer)
        layer = MaxPooling1D(2)(layer)
        layer = Dropout(0.6)(layer)
    
    ## LSTM Layer
    layer = LSTM(LSTM_COUNT, return_sequences=False)(layer)
    layer = Dropout(0.6)(layer)

    ## Dense Layer
    layer = Dense(NUM_HIDDEN, kernel_regularizer=regularizers.l2(L2_regularization), name='dense1')(layer)
    layer = Dropout(0.6)(layer)
    
    ## Softmax Output
    layer = Dense(num_classes)(layer)
    layer = Activation('softmax', name='output_realtime')(layer)
    model_output = layer
    model = Model(model_input, model_output)
    
    
    opt = Adam(lr=0.0005)
    model.compile(
            loss='categorical_crossentropy',
            optimizer=opt,
            metrics=['accuracy']
        )
    
    print(model.summary())
    return model

# %%
path = "./models/crnn/"
os.mkdir(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-42-693a613a2c39> in <module>()
#       1 path = "./models/crnn/"
# ----> 2 os.mkdir(path)
#
# FileNotFoundError: [Errno 2] No such file or directory: './models/crnn/'

# %%
def train_model(x_train, y_train, x_val, y_val):
    
    n_features = x_train.shape[2]
    input_shape = (None, n_features)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
#     tb_callback = TensorBoard(log_dir='./logs/4', histogram_freq=1, batch_size=32, write_graph=True, write_grads=False,
#                               write_images=False, embeddings_freq=0, embeddings_layer_names=None,
#                               embeddings_metadata=None)
    checkpoint_callback = ModelCheckpoint('./models/crnn/weights.best.h5', monitor='val_acc', verbose=1,
                                          save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(
                monitor='val_acc', factor=0.5, patience=10, min_delta=0.01,
                verbose=1
            )
    callbacks_list = [checkpoint_callback, reducelr_callback]

    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCH_COUNT,
                        validation_data=(x_val, y_val), verbose=1, callbacks=callbacks_list)

    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
model, history  = train_model(X_train, y_train, X_valid, y_valid)
# Out:
# Building model...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           (None, None, 128)         0
# _________________________________________________________________
# convolution_1 (SeparableConv (None, None, 56)          7864
# _________________________________________________________________
# batch_normalization_10 (Batc (None, None, 56)          224
# _________________________________________________________________
# activation_10 (Activation)   (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, None, 56)          0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# convolution_2 (SeparableConv (None, None, 56)          3472
# _________________________________________________________________
# batch_normalization_11 (Batc (None, None, 56)          224
# _________________________________________________________________
# activation_11 (Activation)   (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, None, 56)          0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# convolution_3 (SeparableConv (None, None, 56)          3472
# _________________________________________________________________
# batch_normalization_12 (Batc (None, None, 56)          224
# _________________________________________________________________
# activation_12 (Activation)   (None, None, 56)          0
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, None, 56)          0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, None, 56)          0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 96)                58752
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 96)                0
# _________________________________________________________________
# dense1 (Dense)               (None, 64)                6208
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 520
# _________________________________________________________________
# output_realtime (Activation) (None, 8)                 0
# =================================================================
# Total params: 80,960
# Trainable params: 80,624
# Non-trainable params: 336
# _________________________________________________________________
# None
# Training...
# Train on 6394 samples, validate on 800 samples
# Epoch 1/70
# 6394/6394 [==============================] - 43s 7ms/step - loss: 2.5197 - accuracy: 0.1501 - val_loss: 2.3516 - val_accuracy: 0.2075
# Epoch 2/70
# /usr/local/lib/python3.6/dist-packages/keras/callbacks/callbacks.py:707: RuntimeWarning: Can save best model only with val_acc available, skipping.
#   'skipping.' % (self.monitor), RuntimeWarning)
# /usr/local/lib/python3.6/dist-packages/keras/callbacks/callbacks.py:1042: RuntimeWarning: Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: val_loss,val_accuracy,loss,accuracy,lr
#   (self.monitor, ','.join(list(logs.keys()))), RuntimeWarning
# 6394/6394 [==============================] - 41s 6ms/step - loss: 2.3226 - accuracy: 0.2032 - val_loss: 2.1567 - val_accuracy: 0.2438
# Epoch 3/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 2.1661 - accuracy: 0.2637 - val_loss: 2.0667 - val_accuracy: 0.2912
# Epoch 4/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 2.0603 - accuracy: 0.2843 - val_loss: 2.2280 - val_accuracy: 0.2788
# Epoch 5/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.9925 - accuracy: 0.2964 - val_loss: 2.0126 - val_accuracy: 0.3025
# Epoch 6/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.9312 - accuracy: 0.3120 - val_loss: 1.9861 - val_accuracy: 0.3200
# Epoch 7/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.8642 - accuracy: 0.3428 - val_loss: 1.9955 - val_accuracy: 0.3425
# Epoch 8/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.8306 - accuracy: 0.3461 - val_loss: 2.0182 - val_accuracy: 0.3050
# Epoch 9/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.8006 - accuracy: 0.3639 - val_loss: 1.9465 - val_accuracy: 0.3237
# Epoch 10/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.7529 - accuracy: 0.3794 - val_loss: 1.7438 - val_accuracy: 0.3812
# Epoch 11/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.7365 - accuracy: 0.3894 - val_loss: 1.7009 - val_accuracy: 0.3938
# Epoch 12/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.7163 - accuracy: 0.3938 - val_loss: 1.7145 - val_accuracy: 0.3725
# Epoch 13/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.6913 - accuracy: 0.4029 - val_loss: 1.7187 - val_accuracy: 0.3750
# Epoch 14/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.6710 - accuracy: 0.4068 - val_loss: 1.8290 - val_accuracy: 0.3625
# Epoch 15/70
# 6394/6394 [==============================] - 42s 7ms/step - loss: 1.6581 - accuracy: 0.4157 - val_loss: 1.8890 - val_accuracy: 0.3562
# Epoch 16/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.6404 - accuracy: 0.4259 - val_loss: 1.9734 - val_accuracy: 0.3462
# Epoch 17/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.6310 - accuracy: 0.4204 - val_loss: 1.8653 - val_accuracy: 0.3425
# Epoch 18/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.6167 - accuracy: 0.4334 - val_loss: 1.6609 - val_accuracy: 0.3950
# Epoch 19/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.6025 - accuracy: 0.4398 - val_loss: 1.7852 - val_accuracy: 0.3650
# Epoch 20/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.5882 - accuracy: 0.4456 - val_loss: 1.7493 - val_accuracy: 0.3787
# Epoch 21/70
# 6394/6394 [==============================] - 40s 6ms/step - loss: 1.5913 - accuracy: 0.4449 - val_loss: 2.1918 - val_accuracy: 0.2688
# Epoch 22/70
# 6394/6394 [==============================] - 40s 6ms/step - loss: 1.5740 - accuracy: 0.4507 - val_loss: 1.6521 - val_accuracy: 0.3688
# Epoch 23/70
# 6394/6394 [==============================] - 40s 6ms/step - loss: 1.5625 - accuracy: 0.4561 - val_loss: 1.7199 - val_accuracy: 0.3938
# Epoch 24/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.5497 - accuracy: 0.4697 - val_loss: 1.6643 - val_accuracy: 0.3887
# Epoch 25/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.5443 - accuracy: 0.4726 - val_loss: 2.0176 - val_accuracy: 0.3425
# Epoch 26/70
# 6394/6394 [==============================] - 40s 6ms/step - loss: 1.5223 - accuracy: 0.4790 - val_loss: 1.6564 - val_accuracy: 0.4162
# Epoch 27/70
# 6394/6394 [==============================] - 40s 6ms/step - loss: 1.5272 - accuracy: 0.4842 - val_loss: 1.6523 - val_accuracy: 0.4100
# Epoch 28/70
# 6394/6394 [==============================] - 40s 6ms/step - loss: 1.5147 - accuracy: 0.4806 - val_loss: 1.7321 - val_accuracy: 0.4025
# Epoch 29/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.4954 - accuracy: 0.5000 - val_loss: 2.4775 - val_accuracy: 0.2912
# Epoch 30/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.4954 - accuracy: 0.4923 - val_loss: 2.4893 - val_accuracy: 0.2750
# Epoch 31/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.4746 - accuracy: 0.5013 - val_loss: 1.6646 - val_accuracy: 0.4225
# Epoch 32/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.4724 - accuracy: 0.4997 - val_loss: 1.8470 - val_accuracy: 0.4125
# Epoch 33/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.4718 - accuracy: 0.4953 - val_loss: 1.7035 - val_accuracy: 0.4450
# Epoch 34/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.4663 - accuracy: 0.5127 - val_loss: 2.0040 - val_accuracy: 0.3325
# Epoch 35/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.4563 - accuracy: 0.5080 - val_loss: 1.9056 - val_accuracy: 0.3363
# Epoch 36/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.4456 - accuracy: 0.5210 - val_loss: 1.9199 - val_accuracy: 0.3750
# Epoch 37/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.4438 - accuracy: 0.5119 - val_loss: 1.5464 - val_accuracy: 0.4613
# Epoch 38/70
# 6394/6394 [==============================] - 42s 7ms/step - loss: 1.4221 - accuracy: 0.5199 - val_loss: 1.6717 - val_accuracy: 0.4375
# Epoch 39/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.4213 - accuracy: 0.5352 - val_loss: 1.8080 - val_accuracy: 0.4013
# Epoch 40/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.4068 - accuracy: 0.5338 - val_loss: 1.7249 - val_accuracy: 0.4387
# Epoch 41/70
# 6394/6394 [==============================] - 40s 6ms/step - loss: 1.4034 - accuracy: 0.5339 - val_loss: 1.7389 - val_accuracy: 0.4025
# Epoch 42/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.4024 - accuracy: 0.5305 - val_loss: 1.7004 - val_accuracy: 0.4162
# Epoch 43/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.4008 - accuracy: 0.5353 - val_loss: 1.6798 - val_accuracy: 0.4275
# Epoch 44/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.3839 - accuracy: 0.5405 - val_loss: 2.0377 - val_accuracy: 0.3900
# Epoch 45/70
# 6394/6394 [==============================] - 40s 6ms/step - loss: 1.3884 - accuracy: 0.5424 - val_loss: 1.6254 - val_accuracy: 0.4563
# Epoch 46/70
# 6394/6394 [==============================] - 40s 6ms/step - loss: 1.3864 - accuracy: 0.5404 - val_loss: 1.7794 - val_accuracy: 0.4275
# Epoch 47/70
# 6394/6394 [==============================] - 40s 6ms/step - loss: 1.3815 - accuracy: 0.5524 - val_loss: 2.1738 - val_accuracy: 0.3475
# Epoch 48/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.3649 - accuracy: 0.5505 - val_loss: 1.6648 - val_accuracy: 0.4425
# Epoch 49/70
# 6394/6394 [==============================] - 40s 6ms/step - loss: 1.3604 - accuracy: 0.5521 - val_loss: 1.5895 - val_accuracy: 0.4563
# Epoch 50/70
# 6394/6394 [==============================] - 40s 6ms/step - loss: 1.3615 - accuracy: 0.5511 - val_loss: 1.8818 - val_accuracy: 0.3688
# Epoch 51/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.3609 - accuracy: 0.5524 - val_loss: 1.8623 - val_accuracy: 0.3750
# Epoch 52/70
# 6394/6394 [==============================] - 40s 6ms/step - loss: 1.3612 - accuracy: 0.5472 - val_loss: 1.5678 - val_accuracy: 0.4650
# Epoch 53/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.3445 - accuracy: 0.5563 - val_loss: 1.7985 - val_accuracy: 0.4288
# Epoch 54/70
# 6394/6394 [==============================] - 40s 6ms/step - loss: 1.3188 - accuracy: 0.5607 - val_loss: 2.3717 - val_accuracy: 0.3425
# Epoch 55/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.3541 - accuracy: 0.5494 - val_loss: 1.7609 - val_accuracy: 0.4350
# Epoch 56/70
# 6394/6394 [==============================] - 40s 6ms/step - loss: 1.3288 - accuracy: 0.5626 - val_loss: 1.7722 - val_accuracy: 0.4412
# Epoch 57/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.3324 - accuracy: 0.5594 - val_loss: 1.7029 - val_accuracy: 0.4450
# Epoch 58/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.3219 - accuracy: 0.5671 - val_loss: 1.9640 - val_accuracy: 0.3925
# Epoch 59/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.3051 - accuracy: 0.5721 - val_loss: 1.9829 - val_accuracy: 0.3600
# Epoch 60/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.3219 - accuracy: 0.5691 - val_loss: 1.6850 - val_accuracy: 0.4412
# Epoch 61/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.3148 - accuracy: 0.5630 - val_loss: 1.6595 - val_accuracy: 0.4400
# Epoch 62/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.3088 - accuracy: 0.5719 - val_loss: 2.2765 - val_accuracy: 0.3613
# Epoch 63/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.2952 - accuracy: 0.5715 - val_loss: 2.1389 - val_accuracy: 0.3175
# Epoch 64/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.3001 - accuracy: 0.5762 - val_loss: 2.2296 - val_accuracy: 0.3750
# Epoch 65/70
# 6394/6394 [==============================] - 40s 6ms/step - loss: 1.3111 - accuracy: 0.5677 - val_loss: 2.0293 - val_accuracy: 0.3562
# Epoch 66/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.2828 - accuracy: 0.5793 - val_loss: 1.6587 - val_accuracy: 0.4737
# Epoch 67/70
# 6394/6394 [==============================] - 41s 6ms/step - loss: 1.2812 - accuracy: 0.5801 - val_loss: 1.7109 - val_accuracy: 0.4762
# Epoch 68/70
# 6394/6394 [==============================] - 40s 6ms/step - loss: 1.2842 - accuracy: 0.5796 - val_loss: 1.6329 - val_accuracy: 0.4512
# Epoch 69/70
# 6394/6394 [==============================] - 40s 6ms/step - loss: 1.2782 - accuracy: 0.5743 - val_loss: 1.7885 - val_accuracy: 0.4038
# Epoch 70/70
# 6394/6394 [==============================] - 40s 6ms/step - loss: 1.2917 - accuracy: 0.5785 - val_loss: 2.1168 - val_accuracy: 0.3638

# %%
show_summary_stats(history)
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy', 'lr'])

# %%
from sklearn.metrics import classification_report

y_true = np.argmax(y_valid, axis = 1)
y_pred = model.predict(X_valid)
y_pred = np.argmax(y_pred, axis=1)
labels = [0,1,2,3,4,5,6,7]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# (800,) (800,)
#                precision    recall  f1-score   support
#
#    Electronic       0.46      0.41      0.43       100
#  Experimental       0.56      0.32      0.41       100
#          Folk       0.52      0.66      0.58       100
#       Hip-Hop       0.66      0.47      0.55       100
#  Instrumental       0.45      0.28      0.35       100
# International       0.30      0.80      0.43       100
#           Pop       0.15      0.06      0.09       100
#          Rock       0.53      0.44      0.48       100
#
#      accuracy                           0.43       800
#     macro avg       0.45      0.43      0.41       800
#  weighted avg       0.45      0.43      0.41       800

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_true, y_pred))
# Out:
# 0.43

# %% [markdown]
# ### Connect to Test Set

# %%
from keras.models import load_model

weights_path = 'models/crnn/weights.best.h5'
model = load_model(weights_path)
# Out:
# WARNING:tensorflow:From /home/priya/miniconda3/envs/exptt/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:497: calling conv1d (from tensorflow.python.ops.nn_ops) with data_format=NHWC is deprecated and will be removed in a future version.
# Instructions for updating:
# `NHWC` for data_format is deprecated, use `NWC` instead

# %%
npzfile = np.load('test_arr.npz')
print(npzfile.files)
X_test = npzfile['arr_0']
y_test = npzfile['arr_1']
print(X_test.shape, y_test.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
y_test -= 1
print(np.amin(y_test), np.amax(y_test), np.mean(y_test))
# Out:
# 0 7 3.5

# %%
X_test_raw = librosa.core.db_to_power(X_test, ref=1.0)
print(np.amin(X_test_raw), np.amax(X_test_raw), np.mean(X_test_raw))
# Out:
# 1e-08 1.0000000000000016 0.004623813018385694

# %%
X_test = np.log(X_test_raw)


from sklearn.metrics import classification_report

y_true = y_test
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
labels = [0,1,2,3,4,5,6,7]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# (800,) (800,)
#                precision    recall  f1-score   support
#
#    Electronic       0.64      0.49      0.55       100
#  Experimental       0.28      0.22      0.25       100
#          Folk       0.19      0.16      0.17       100
#       Hip-Hop       0.57      0.85      0.68       100
#  Instrumental       0.36      0.34      0.35       100
# International       0.46      0.64      0.54       100
#           Pop       0.30      0.27      0.28       100
#          Rock       0.64      0.56      0.60       100
#
#     micro avg       0.44      0.44      0.44       800
#     macro avg       0.43      0.44      0.43       800
#  weighted avg       0.43      0.44      0.43       800

# %%
y_test = keras.utils.to_categorical(y_test, num_classes=8)
model.evaluate(X_test, y_test)
# Out:
# 800/800 [==============================] - 1s 707us/step
# [1.7413653707504273, 0.44125]

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_true, y_pred))
# Out:
# [[49  1  6 16  5 13  8  2]
#  [ 9 22  8  9 21 17  7  7]
#  [ 0 27 16  1 17 14 19  6]
#  [ 3  2  1 85  1  6  2  0]
#  [ 3 18 29  1 34  8  5  2]
#  [ 3  1 10  9  3 64  6  4]
#  [ 7  2  9 28  4 12 27 11]
#  [ 3  6  4  1  9  4 17 56]]

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_true, y_pred))
# Out:
# 0.44125

# %%
### 8 clusters
from sklearn.metrics import confusion_matrix
import seaborn as sns


mat = confusion_matrix(y_true, y_pred)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,
            xticklabels=dict_genres.keys(),
            yticklabels=dict_genres.keys())
plt.xlabel('true label')
plt.ylabel('predicted label');
